# %% [markdown]
# # 공간정보
# - 브이월드 공간정보다운로드 국토부
# - https://www.vworld.kr/dtmk/dtmk_ntads_s001.do
# - 국토관리 지역개발 행정구역시군구_경계

# %%
# !pip install matplotlib

# %%
# !sudo -S apt update

# %%
# OS에 사용가능한 , 설치된 폰트를 나열
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm

# %%
# 리눅스용 폰트 경로 설정
plt.rc('font', family="NanumGothic")
plt.text(0.2,0.4,'한글',size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /home/pkys/.local/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /home/pkys/.local/lib/python3.10/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/pkys/.local/lib/python3.10/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in /home/pkys/.local/lib/python3.10/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /home/pkys/.local/lib/python3.10/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in /home/pkys/.local/lib/python3.10/site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /home/pkys/.local/lib/python3.10/site-packages (from geopandas) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pkys/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pkys/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/pkys/.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2025.1)
# Requirement already satisfied: certifi in /home/pkys/.local/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /home/pkys/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)

# %%
# !export PATH=$PATH:/home/pkys/.local/bin

# %%
import geopandas as gpd
shp_path = "./ref/LARD_ADM_SECT_SGG_26_202502.shp"
gdf = gpd.read_file(shp_path, encoding="EUC-KR")
print(gdf)
#컬러맵 설정
fig , ax = plt.subplots(1,1,figsize=(13,10))
gdf.plot(column = "SGG_NM", ax =ax ,legend=True , cmap ='tab20')

plt.show()
# Out:
#    ADM_SECT_C SGG_NM  SGG_OID COL_ADM_SE  \
# 0       26380    사하구      166      26380
# 1       26530    사상구      190      26530
# 2       26260    동래구      193      26260
# 3       26410    금정구      194      26410
# 4       26470    연제구       14      26470
# 5       26500    수영구       62      26500
# 6       26230   부산진구       66      26230
# 7       26350   해운대구       17      26350
# 8       26110     중구       71      26110
# 9       26290     남구      135      26290
# 10      26170     동구      138      26170
# 11      26200    영도구      142      26200
# 12      26320     북구      116      26320
# 13      26710    기장군      161      26710
# 14      26140     서구      245      26140
# 15      26440    강서구      246      26440
#
#                                              geometry
# 0   MULTIPOLYGON (((378432.999 256054.721, 378450....
# 1   POLYGON ((378841.663 284038.046, 378605.963 28...
# 2   MULTIPOLYGON (((392620.066 290091.15, 392623.4...
# 3   POLYGON ((392212.804 292563.624, 392212.804 29...
# 4   MULTIPOLYGON (((389312.792 288505.293, 389304....
# 5   POLYGON ((391476.376 285962.541, 391366.315 28...
# 6   POLYGON ((389340.245 287309.49, 389383.713 287...
# 7   MULTIPOLYGON (((402025.013 288121.121, 402025....
# 8   POLYGON ((385862.953 280199.68, 385864.541 280...
# 9   MULTIPOLYGON (((391432.472 279267.529, 391108....
# 10  POLYGON ((384542.863 282156.184, 384603.073 28...
# 11  MULTIPOLYGON (((390917.615 273222.432, 390919....
# 12  POLYGON ((381023.284 291255.915, 381331.237 29...
# 13  MULTIPOLYGON (((403661.729 297996.986, 403684....
# 14  MULTIPOLYGON (((383782.745 274389.318, 383785....
# 15  MULTIPOLYGON (((362109.131 269803.853, 362136....

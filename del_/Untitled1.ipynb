# %%
# !pwd
# Out:
# /home/pkys/data

# %%
# Out:
# total 3744
# drwxrwxrwx 1 root root    4096 Mar 10 03:28  .
# drwxr-x--- 1 pkys pkys    4096 Mar 10 03:24  ..
# -rwxrwxrwx 1 root root     167 Feb 25 08:00  .env
# drwxrwxrwx 1 root root    4096 Mar  7 06:14  .git
# -rwxrwxrwx 1 root root      83 Feb 14 02:17  .gitignore
# drwxr-xr-x 1 pkys pkys    4096 Mar 10 03:28  .ipynb_checkpoints
# drwxr-xr-x 1 pkys users   4096 Mar 10 00:24  .ipython
# drwxr-xr-x 1 pkys users   4096 Mar 10 00:30  .jupyter
# drwxr-xr-x 1 pkys users   4096 Mar 10 00:24  .local
# drwxr-xr-x 1 pkys users   4096 Mar 10 00:24  .npm
# -rwxrwxrwx 1 root root      74 Feb  6 00:11  .start_jupyter.bat
# drwxrwxrwx 1 root root    4096 Mar  9 23:56  .virtual_documents
# -rwxrwxrwx 1 root root     105 Feb 14 02:16  README.md
# -rw-r--r-- 1 pkys pkys      72 Mar 10 03:25  Untitled.ipynb
# -rw-r--r-- 1 pkys pkys      72 Mar 10 03:28  Untitled1.ipynb
# drwxrwxrwx 1 root root    4096 Feb 25 05:46  __pycache__
# drwxrwxrwx 1 root root    4096 Mar  5 03:02  chart
# ...
